# %% [markdown]
# <a href="https://colab.research.google.com/github/krishnadixit05/Google-Colab/blob/main/Post_lab_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets

# %%
#1. Read the dataset
dataset=pd.read_csv("/content/NPHA-doctor-visits.csv")
X=dataset.iloc[:, :2].values
y=dataset.iloc[:, 2].values

# %%
dataset.describe()
# Out:
#        Number of Doctors Visited    Age  Phyiscal Health  Mental Health  \
# count                 714.000000  714.0       714.000000     714.000000
# mean                    2.112045    2.0         2.794118       1.988796
# std                     0.683441    0.0         0.900939       0.939928
# min                     1.000000    2.0        -1.000000      -1.000000
# 25%                     2.000000    2.0         2.000000       1.000000
# 50%                     2.000000    2.0         3.000000       2.000000
# 75%                     3.000000    2.0         3.000000       3.000000
# max                     3.000000    2.0         5.000000       5.000000
#
#        Dental Health  Employment  Stress Keeps Patient from Sleeping  \
# count     714.000000  714.000000                          714.000000
# mean        3.009804    2.806723                            0.247899
# std         1.361117    0.586582                            0.432096
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.50)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.fit_transform(X_test)

# %%
from sklearn.naive_bayes import BernoulliNB;
from sklearn.naive_bayes import GaussianNB;
#classifier=BernoulliNB()
classifier=GaussianNB()
classifier.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred=classifier.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[  0,   0,   1,   0,   0,   0],
#        [  0,   0,  13,   3,   0,   0],
#        [  0,   0,  90,  24,   0,   0],
#        [  0,   0, 108,  40,   0,   0],
#        [  0,   0,  39,  23,   0,   0],
#        [  0,   0,  10,   6,   0,   0]])

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_pred, y_test)
# Out:
# 0.3641456582633053
